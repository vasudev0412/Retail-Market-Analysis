# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os

# %%
customer = pd.read_csv("G:/Data Science Recorded Lectures/case studies/3. Pandas Case Study 1 - Retail Case Study (1)/3. Pandas Case Study 1 - Retail Case Study/Customer.csv")
prod_info = pd.read_csv("G:/Data Science Recorded Lectures/case studies/3. Pandas Case Study 1 - Retail Case Study (1)/3. Pandas Case Study 1 - Retail Case Study/prod_cat_info.csv")
transaction = pd.read_csv("G:/Data Science Recorded Lectures/case studies/3. Pandas Case Study 1 - Retail Case Study (1)/3. Pandas Case Study 1 - Retail Case Study/Transactions.csv")

# %%
customer.shape
# Out:
# (5647, 4)

# %%
prod_info.shape
# Out:
# (23, 4)

# %%
transaction.shape
# Out:
# (23053, 10)

# %%
customer.head(2)
# Out:
#    customer_Id         DOB Gender  city_code
# 0       268408  02-01-1970      M        4.0
# 1       269696  07-01-1970      F        8.0

# %%
prod_info.head(2)
# Out:
#    prod_cat_code  prod_cat  prod_sub_cat_code prod_subcat
# 0              1  Clothing                  4        Mens
# 1              1  Clothing                  1       Women

# %%
# renaming "prod_sub_cat_code" column in 'prod_info' table to make it similar to 'transaction' table
# to merge the both the tables easily
prod_info.rename(columns={"prod_sub_cat_code":"prod_subcat_code"},inplace=True)

# %%
transaction.head()
# Out:
#    transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351  28-02-2014                 1              1   -5
# 1     29258453508   270384  27-02-2014                 5              3   -5
# 2     51750724947   273420  24-02-2014                 6              5   -2
# 3     93274880719   271509  24-02-2014                11              6   -3
# 4     51750724947   273420  23-02-2014                 6              5   -2
#
#    Rate      Tax  total_amt Store_type
# 0  -772  405.300  -4265.300     e-Shop
# 1 -1497  785.925  -8270.925     e-Shop
# 2  -791  166.110  -1748.110   TeleShop
# 3 -1363  429.345  -4518.345     e-Shop
# 4  -791  166.110  -1748.110   TeleShop

# %% [markdown]
# #### 1. Merge the datasets Customers, Product Hierarchy and Transactions as Customer_Final
# #### Merge 'transaction' and 'prod_info' tables

# %%
# merge transaction and prod_info table and create a new table "prod_concat"
prod_concat = pd.merge(left=transaction, right=prod_info,
                       on=["prod_cat_code","prod_subcat_code"],how="left")

# %%
prod_concat
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# 5         97439039119   272357  23-02-2014                 8              3
# 6         45649838090   273667  22-02-2014                11              6
# 7         22643667930   271489  22-02-2014                12              6
# 8         79792372943   275108  22-02-2014                 3              1
# 9         50076728598   269014  21-02-2014                 8              3
# 10        29258453508   270384  20-02-2014                 5              3
# 11        25455265351   267750  20-02-2014                12              6
# 12         1571002198   275023  20-02-2014                 6              5
# 13        43134751727   268487  20-02-2014                 3              2
# 14        36554696014   269345  20-02-2014                 3              5
# 15        56814940239   268799  20-02-2014                 7              5
# 16        54295803788   270787  20-02-2014                12              5
# 17        25963520987   274829  20-02-2014                 4              4
# 18        17183929085   266863  20-02-2014                 1              2
# 15       5   368  193.200   2033.200          e-Shop             Books
# 16       5   584  306.600   3226.600          e-Shop             Books
# 17       3   502  158.130   1664.130  Flagship store              Bags
# 18       1  1359  142.695   1501.695        TeleShop          Footwear
# 19       3   825  259.875   2734.875        TeleShop          Clothing
# 20       4   846  355.320   3739.320        TeleShop             Books
# 21       3  1384  435.960   4587.960        TeleShop             Books
# 22       3  1203  378.945   3987.945        TeleShop       Electronics
# 23       4  1243  522.060   5494.060             MBR          Footwear
# 24       1   877   92.085    969.085          e-Shop       Electronics
# 25       1    76    7.980     83.980        TeleShop             Books
# 26       5   772  405.300   4265.300          e-Shop          Clothing
# 27       2   474   99.540   1047.540        TeleShop       Electronics
# 28      -3   -80   25.200   -265.200             MBR              Bags
# 29       1    96   10.080    106.080  Flagship store          Footwear
# ...    ...   ...      ...        ...             ...               ...
# 23023    1   963  101.115   1064.115  Flagship store              Bags
# 23024    3   474  149.310   1571.310          e-Shop          Footwear
# 23025    4  1114  467.880   4923.880          e-Shop             Books
# 23026    4  1198  503.160   5295.160        TeleShop       Electronics
# 23027    5   295  154.875   1629.875  Flagship store       Electronics
# 23028    2   378   79.380    835.380             MBR  Home and kitchen
# 23029    5   217  113.925   1198.925          e-Shop          Footwear
# 23030    3  1128  355.320   3739.320  Flagship store  Home and kitchen
# 23031    4  1477  620.340   6528.340          e-Shop              Bags
# 23032    4  1408  591.360   6223.360          e-Shop             Books
# 23033    1   276   28.980    304.980  Flagship store          Clothing
# 23034    1   334   35.070    369.070             MBR       Electronics
# 23035    3   147   46.305    487.305             MBR          Clothing
# 23036    5   941  494.025   5199.025        TeleShop             Books
# 23037    1   333   34.965    367.965          e-Shop             Books
# 23038    4  1447  607.740   6395.740          e-Shop              Bags
# 23039    5   631  331.275   3486.275  Flagship store          Footwear
# 23040    4   728  305.760   3217.760             MBR          Footwear
# 23041    5    71   37.275    392.275          e-Shop  Home and kitchen
# 23042    2   276   57.960    609.960          e-Shop       Electronics
# 23043    4  1330  558.600   5878.600          e-Shop             Books
# 23044    5   969  508.725   5353.725          e-Shop       Electronics
# 23045    1  1148  120.540   1268.540        TeleShop             Books
# 23046    3  1077  339.255   3570.255          e-Shop  Home and kitchen
# 23047    2   444   93.240    981.240        TeleShop          Footwear
# 23048    1  1264  132.720   1396.720          e-Shop             Books
# 23049    1   677   71.085    748.085          e-Shop          Clothing
# 23050    4  1052  441.840   4649.840             MBR  Home and kitchen
# 23051    3  1142  359.730   3785.730        TeleShop             Books
# 23052    1   447   46.935    493.935        TeleShop             Books
#
#                prod_subcat
# 0                    Women
# 1                Computers
# 2                      DIY
# 3                     Bath
# 4                      DIY
# 5      Personal Appliances
# 6                     Bath
# 7                    Tools
# 8                     Kids
# 9      Personal Appliances
# 10               Computers
# 11                   Tools
# 12                     DIY
# 13                   Women
# 14                  Comics
# 15                 Fiction
# 16                Academic
# 17                   Women
# 18                    Mens
# 19                    Kids
# 20                Children
# 21                 Fiction
# 22               Computers
# 23                    Mens
# 24                 Cameras
# 25                  Comics
# 26                   Women
# 27         Audio and video
# 28                   Women
# 29                   Women
# ...                    ...
# 23023                Women
# 23024                Women
# 23025               Comics
# 23026            Computers
# 23027  Personal Appliances
# 23028                Tools
# 23029                 Mens
# 23030                 Bath
# 23031                Women
# 23032          Non-Fiction
# 23033                 Kids
# 23034              Cameras
# 23035                 Kids
# 23036          Non-Fiction
# 23037               Comics
# 23038                Women
# 23039                Women
# 23040                Women
# 23041           Furnishing
# 23042            Computers
# 23043          Non-Fiction
# 23044              Mobiles
# 23045                  DIY
# 23046                 Bath
# 23047                 Kids
# 23048             Academic
# 23049                 Mens
# 23050           Furnishing
# 23051             Children
# 23052             Children
#
# [23053 rows x 12 columns]

# %%
prod_concat.isnull().sum()
# Out:
# transaction_id      0
# cust_id             0
# tran_date           0
# prod_subcat_code    0
# prod_cat_code       0
# Qty                 0
# Rate                0
# Tax                 0
# total_amt           0
# Store_type          0
# prod_cat            0
# prod_subcat         0
# dtype: int64

# %% [markdown]
# ##### Merge 'customer' and 'prod_concat' tables

# %%
customer.head()
# Out:
#    customer_Id         DOB Gender  city_code
# 0       268408  02-01-1970      M        4.0
# 1       269696  07-01-1970      F        8.0
# 2       268159  08-01-1970      F        8.0
# 3       270181  10-01-1970      F        2.0
# 4       268073  11-01-1970      M        1.0

# %%
#merge "prod_concat" and "customer" table and create the final table "customer_final"
customer_final = pd.merge(left=prod_concat, right=customer,right_on="customer_Id", left_on="cust_id", how="left")

# %%
customer_final.head()
# Out:
#    transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351  28-02-2014                 1              1   -5
# 1     29258453508   270384  27-02-2014                 5              3   -5
# 2     51750724947   273420  24-02-2014                 6              5   -2
# 3     93274880719   271509  24-02-2014                11              6   -3
# 4     51750724947   273420  23-02-2014                 6              5   -2
#
#    Rate      Tax  total_amt Store_type          prod_cat prod_subcat  \
# 0  -772  405.300  -4265.300     e-Shop          Clothing       Women
# 1 -1497  785.925  -8270.925     e-Shop       Electronics   Computers
# 2  -791  166.110  -1748.110   TeleShop             Books         DIY
# 3 -1363  429.345  -4518.345     e-Shop  Home and kitchen        Bath
# 4  -791  166.110  -1748.110   TeleShop             Books         DIY
#
#    customer_Id         DOB Gender  city_code
# 0       270351  26-09-1981      M        5.0
# 1       270384  11-05-1973      F        8.0
# 2       273420  27-07-1992      M        8.0
# 3       271509  08-06-1981      M        3.0
# 4       273420  27-07-1992      M        8.0

# %%
customer_final.shape
# Out:
# (23053, 16)

# %%
transaction.shape
# Out:
# (23053, 10)

# %%
print('''Rows of both the 'customer_final' and 'transaction' table are same. That means all the transactions done at the 
         Retail Store are present in the final table ''')
# Out:
# Rows of both the 'customer_final' and 'transaction' table are same. That means all the transactions done at the
#          Retail Store are present in the final table

# %%
customer_final.dtypes
# Out:
# transaction_id        int64
# cust_id               int64
# tran_date            object
# prod_subcat_code      int64
# prod_cat_code         int64
# Qty                   int64
# Rate                  int64
# Tax                 float64
# total_amt           float64
# Store_type           object
# prod_cat             object
# prod_subcat          object
# customer_Id           int64
# DOB                  object
# Gender               object
# city_code           float64
# dtype: object

# %%
customer_final.isnull().sum()
# Out:
# transaction_id      0
# cust_id             0
# tran_date           0
# prod_subcat_code    0
# prod_cat_code       0
# Qty                 0
# Rate                0
# Tax                 0
# total_amt           0
# Store_type          0
# prod_cat            0
# prod_subcat         0
# customer_Id         0
# DOB                 0
# Gender              9
# city_code           8
# dtype: int64

# %%
# converting "DOB" and "tran_date" from object dtype to dates
customer_final["DOB"] = pd.to_datetime(customer_final["DOB"], format="%d-%m-%Y")

# %%
customer_final['DOB'].head(10)
# Out:
# 0   1981-09-26
# 1   1973-05-11
# 2   1992-07-27
# 3   1981-06-08
# 4   1992-07-27
# 5   1982-10-09
# 6   1981-05-29
# 7   1971-04-21
# 8   1971-11-04
# 9   1979-11-27
# Name: DOB, dtype: datetime64[ns]

# %%
customer_final["tran_date"] = pd.to_datetime(customer_final["tran_date"])

# %%
customer_final["tran_date"].head(10)
# Out:
# 0   2014-02-28
# 1   2014-02-27
# 2   2014-02-24
# 3   2014-02-24
# 4   2014-02-23
# 5   2014-02-23
# 6   2014-02-22
# 7   2014-02-22
# 8   2014-02-22
# 9   2014-02-21
# Name: tran_date, dtype: datetime64[ns]

# %% [markdown]
# ## Checking for duplicate values

# %%
customer_final.duplicated().sum()
# Out:
# 13

# %%
# dropping duplicate rows
customer_final.drop_duplicates(inplace=True)

# %%
customer_final.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### 2. Prepare a summary report for the merged data set.

# %% [markdown]
# ##### (a) Get the column names and their corresponding data types

# %%
#column names of "customer_final" dataframe
customer_final.columns
# Out:
# Index(['transaction_id', 'cust_id', 'tran_date', 'prod_subcat_code',
#        'prod_cat_code', 'Qty', 'Rate', 'Tax', 'total_amt', 'Store_type',
#        'prod_cat', 'prod_subcat', 'customer_Id', 'DOB', 'Gender', 'city_code'],
#       dtype='object')

# %%
# data types of all columns of "customer_final" dataframe
customer_final.dtypes
# Out:
# transaction_id               int64
# cust_id                      int64
# tran_date           datetime64[ns]
# prod_subcat_code             int64
# prod_cat_code                int64
# Qty                          int64
# Rate                         int64
# Tax                        float64
# total_amt                  float64
# Store_type                  object
# prod_cat                    object
# prod_subcat                 object
# customer_Id                  int64
# DOB                 datetime64[ns]
# Gender                      object
# city_code                  float64
# dtype: object

# %% [markdown]
# #### (b) Top/Bottom 10 observations

# %%
# top 10 observations
customer_final.head(10)
# Out:
#    transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351 2014-02-28                 1              1   -5
# 1     29258453508   270384 2014-02-27                 5              3   -5
# 2     51750724947   273420 2014-02-24                 6              5   -2
# 3     93274880719   271509 2014-02-24                11              6   -3
# 4     51750724947   273420 2014-02-23                 6              5   -2
# 5     97439039119   272357 2014-02-23                 8              3   -2
# 6     45649838090   273667 2014-02-22                11              6   -1
# 7     22643667930   271489 2014-02-22                12              6   -1
# 8     79792372943   275108 2014-02-22                 3              1   -3
# 9     50076728598   269014 2014-02-21                 8              3   -4
#
#    Rate      Tax  total_amt Store_type          prod_cat          prod_subcat  \
# 0  -772  405.300  -4265.300     e-Shop          Clothing                Women
# 1 -1497  785.925  -8270.925     e-Shop       Electronics            Computers
# 2  -791  166.110  -1748.110   TeleShop             Books                  DIY
# 3 -1363  429.345  -4518.345     e-Shop  Home and kitchen                 Bath
# 4  -791  166.110  -1748.110   TeleShop             Books                  DIY
# 5  -824  173.040  -1821.040   TeleShop       Electronics  Personal Appliances
# 6 -1450  152.250  -1602.250     e-Shop  Home and kitchen                 Bath
# 7 -1225  128.625  -1353.625   TeleShop  Home and kitchen                Tools
# 8  -908  286.020  -3010.020        MBR          Clothing                 Kids
# 9  -581  244.020  -2568.020     e-Shop       Electronics  Personal Appliances
#
#    customer_Id        DOB Gender  city_code
# 0       270351 1981-09-26      M        5.0
# 1       270384 1973-05-11      F        8.0
# 2       273420 1992-07-27      M        8.0
# 3       271509 1981-06-08      M        3.0
# 4       273420 1992-07-27      M        8.0
# 5       272357 1982-10-09      F        6.0
# 6       273667 1981-05-29      M        9.0
# 7       271489 1971-04-21      M        9.0
# 8       275108 1971-11-04      F        8.0
# 9       269014 1979-11-27      F        3.0

# %%
#bottom 10 observations
customer_final.tail(10)
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 23043     49882891062   271982 2011-01-25                10              5
# 23044     14787475597   273982 2011-01-25                 4              3
# 23045     50691119572   273031 2011-01-25                 6              5
# 23046     40893803228   272049 2011-01-25                11              6
# 23047     30856003613   266866 2011-01-25                 4              2
# 23048     94340757522   274550 2011-01-25                12              5
# 23049     89780862956   270022 2011-01-25                 4              1
# 23050     85115299378   271020 2011-01-25                 2              6
# 23051     72870271171   270911 2011-01-25                11              5
# 23052     77960931771   271961 2011-01-25                11              5
#
#        Qty  Rate      Tax  total_amt Store_type          prod_cat  \
# 23043    4  1330  558.600   5878.600     e-Shop             Books
# 23044    5   969  508.725   5353.725     e-Shop       Electronics
# 23045    1  1148  120.540   1268.540   TeleShop             Books
# 23046    3  1077  339.255   3570.255     e-Shop  Home and kitchen
# 23047    2   444   93.240    981.240   TeleShop          Footwear
# 23048    1  1264  132.720   1396.720     e-Shop             Books
# 23049    1   677   71.085    748.085     e-Shop          Clothing
# 23050    4  1052  441.840   4649.840        MBR  Home and kitchen
# 23051    3  1142  359.730   3785.730   TeleShop             Books
# 23052    1   447   46.935    493.935   TeleShop             Books
#
#        prod_subcat  customer_Id        DOB Gender  city_code
# 23043  Non-Fiction       271982 1976-08-10      M        8.0
# 23044      Mobiles       273982 1991-10-12      M        4.0
# 23045          DIY       273031 1980-01-17      F        8.0
# 23046         Bath       272049 1975-06-28      F        6.0
# 23047         Kids       266866 1974-04-18      M        4.0
# 23048     Academic       274550 1972-02-21      M        7.0
# 23049         Mens       270022 1984-04-27      M        9.0
# 23050   Furnishing       271020 1976-06-20      M        8.0
# 23051     Children       270911 1970-05-22      M        2.0
# 23052     Children       271961 1982-01-15      M        1.0

# %% [markdown]
# #### (c) “Five-number summary” for continuous variables (min, Q1, median, Q3 and max)

# %%
customer_final.describe()
# Out:
#        transaction_id        cust_id  prod_subcat_code  prod_cat_code  \
# count    2.304000e+04   23040.000000      23040.000000   23040.000000
# mean     5.006955e+10  271021.880252          6.148785       3.763498
# std      2.898062e+10    2431.573668          3.726197       1.677091
# min      3.268991e+06  266783.000000          1.000000       1.000000
# 25%      2.493315e+10  268935.000000          3.000000       2.000000
# 50%      5.009188e+10  270980.500000          5.000000       4.000000
# 75%      7.532632e+10  273114.250000         10.000000       5.000000
# max      9.998755e+10  275265.000000         12.000000       6.000000
#
#                 Qty          Rate           Tax     total_amt    customer_Id  \
# count  23040.000000  23040.000000  23040.000000  23040.000000   23040.000000
# mean       2.435764    637.094965    248.677488   2109.865226  271021.880252
# std        2.264326    621.727374    187.188311   2505.610295    2431.573668
# min       -5.000000  -1499.000000      7.350000  -8270.925000  266783.000000
# 25%        1.000000    312.000000     98.280000    762.450000  268935.000000
# 50%        3.000000    710.000000    199.080000   1756.950000  270980.500000
# 75%        4.000000   1109.000000    365.767500   3570.255000  273114.250000
# max        5.000000   1500.000000    787.500000   8287.500000  275265.000000
#
#           city_code
# count  23032.000000
# mean       5.483067
# std        2.863331
# min        1.000000
# 25%        3.000000
# 50%        5.000000
# 75%        8.000000
# max       10.000000

# %% [markdown]
# #### (d) Frequency tables for all the categorical variables

# %%
customer_final.loc[:,customer_final.dtypes=="object"].describe()
# Out:
#        Store_type prod_cat prod_subcat Gender
# count       23040    23040       23040  23031
# unique          4        6          18      2
# top        e-Shop    Books       Women      M
# freq         9304     6066        3046  11804

# %% [markdown]
# #### (3) Generate histograms for all continuous variables and frequency bars for categorical variables

# %% [markdown]
# ### Histogram of all continuous variables

# %%
conti_customer = customer_final.loc[:,['prod_subcat_code','prod_cat_code', 'Qty', 'Rate', 'Tax', 'total_amt']]

# %%
conti_customer.columns
# Out:
# Index(['prod_subcat_code', 'prod_cat_code', 'Qty', 'Rate', 'Tax', 'total_amt'], dtype='object')

# %%
for var in conti_customer.columns:
    conti_customer[var].plot(kind='hist')
    plt.title(var)
    plt.show()

# %% [markdown]
# #### Bar chart of categorical variables

# %%
category_customer = customer_final.loc[:,customer_final.dtypes=='object']

# %%
category_customer.head()
# Out:
#   Store_type          prod_cat prod_subcat Gender
# 0     e-Shop          Clothing       Women      M
# 1     e-Shop       Electronics   Computers      F
# 2   TeleShop             Books         DIY      M
# 3     e-Shop  Home and kitchen        Bath      M
# 4   TeleShop             Books         DIY      M

# %%
plt.figure(figsize=(8,8))
sns.countplot(category_customer['Gender'])
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(category_customer['Store_type'])
plt.xlabel('Store Type')
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(category_customer['prod_cat'])
plt.xlabel('Product Category')
plt.show()

# %%
plt.figure(figsize=(8,8))
category_customer.groupby('prod_subcat')['prod_subcat'].count().plot(kind='barh')
plt.xlabel('Count')
plt.ylabel('Product Subcategory')
plt.show()

# %% [markdown]
# #### (4) Calculate the following information using the merged dataset:
# #### (a) Time period of the available transaction data

# %%
customer_final.sort_values(by="tran_date")
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code
# 162        Audio and video       274678 1975-05-20      F        9.0
# 147             Furnishing       275246 1970-06-25      M        3.0
# 154    Personal Appliances       271180 1987-11-08      M        4.0
# 146               Academic       274897 1987-09-16      M        2.0
#
# [23040 rows x 16 columns]

# %%
min_date = customer_final["tran_date"].min()

# %%
max_date = customer_final["tran_date"].max()

# %%
print("Time period of the available transaction data is from "+ pd.Timestamp.strftime(min_date,format="%d-%m-%Y") + " to " + pd.Timestamp.strftime(max_date,format="%d-%m-%Y"))
# Out:
# Time period of the available transaction data is from 02-01-2011 to 02-12-2014

# %% [markdown]
# #### (b) Count of transactions where the total amount of transaction was negative

# %%
customer_final.head()
# Out:
#    transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351 2014-02-28                 1              1   -5
# 1     29258453508   270384 2014-02-27                 5              3   -5
# 2     51750724947   273420 2014-02-24                 6              5   -2
# 3     93274880719   271509 2014-02-24                11              6   -3
# 4     51750724947   273420 2014-02-23                 6              5   -2
#
#    Rate      Tax  total_amt Store_type          prod_cat prod_subcat  \
# 0  -772  405.300  -4265.300     e-Shop          Clothing       Women
# 1 -1497  785.925  -8270.925     e-Shop       Electronics   Computers
# 2  -791  166.110  -1748.110   TeleShop             Books         DIY
# 3 -1363  429.345  -4518.345     e-Shop  Home and kitchen        Bath
# 4  -791  166.110  -1748.110   TeleShop             Books         DIY
#
#    customer_Id        DOB Gender  city_code
# 0       270351 1981-09-26      M        5.0
# 1       270384 1973-05-11      F        8.0
# 2       273420 1992-07-27      M        8.0
# 3       271509 1981-06-08      M        3.0
# 4       273420 1992-07-27      M        8.0

# %%
#count of transaction_ids where total_amt was negative
negative_transaction = customer_final.loc[customer_final["total_amt"] < 0,"transaction_id"].count()

# %%
print("Count of transactions where the total amount of transaction was negative is",negative_transaction)
# Out:
# Count of transactions where the total amount of transaction was negative is 2164

# %% [markdown]
# #### (5) Analyze which product categories are more popular among females vs male customers

# %%
#groupby the data set on the basis of "Gender" and "prod_cat"
product_gender = customer_final.groupby(["Gender","prod_cat"])[["Qty"]].sum().reset_index()

# %%
product_gender
# Out:
#    Gender          prod_cat   Qty
# 0       F              Bags  2364
# 1       F             Books  7080
# 2       F          Clothing  3425
# 3       F       Electronics  5832
# 4       F          Footwear  3721
# 5       F  Home and kitchen  4898
# 6       M              Bags  2346
# 7       M             Books  7587
# 8       M          Clothing  3748
# 9       M       Electronics  6486
# 10      M          Footwear  3561
# 11      M  Home and kitchen  5051

# %%
#converting to pivot table for better view
product_gender.pivot(index="Gender",columns="prod_cat",values="Qty")
# Out:
# prod_cat  Bags  Books  Clothing  Electronics  Footwear  Home and kitchen
# Gender
# F         2364   7080      3425         5832      3721              4898
# M         2346   7587      3748         6486      3561              5051

# %% [markdown]
# Products that are popular among males are:
#
# Books
# Clothing
# Electronics
# Home and kitchen
# Products that are popular among females are:
#     Bags
#     Footwear

# %% [markdown]
# #### (6) Which City code has the maximum customers and what was the percentage of customers from that city?

# %%
customer_final.head(2)
# Out:
#    transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351 2014-02-28                 1              1   -5
# 1     29258453508   270384 2014-02-27                 5              3   -5
#
#    Rate      Tax  total_amt Store_type     prod_cat prod_subcat  customer_Id  \
# 0  -772  405.300  -4265.300     e-Shop     Clothing       Women       270351
# 1 -1497  785.925  -8270.925     e-Shop  Electronics   Computers       270384
#
#          DOB Gender  city_code
# 0 1981-09-26      M        5.0
# 1 1973-05-11      F        8.0

# %%
customer_group = customer_final.groupby('city_code')['customer_Id'].count().sort_values(ascending =False)

# %%
customer_group
# Out:
# city_code
# 4.0     2422
# 3.0     2410
# 5.0     2357
# 7.0     2356
# 10.0    2333
# 8.0     2328
# 2.0     2268
# 1.0     2255
# 9.0     2176
# 6.0     2127
# Name: customer_Id, dtype: int64

# %%
plt.figure(figsize=(8,5))
customer_group.plot(kind="bar")
plt.xlabel("City Code")
plt.ylabel("No. of customers")
plt.yticks(np.arange(0, 3500, step=500))
plt.show()

# %%
percentage = round((customer_group[4.0] / customer_group.sum()) * 100,2)

# %%
percentage
# Out:
# 10.52

# %%
print("City code 4.0 has the maximum customers and the percentage of customers from that city is ",percentage)
# Out:
# City code 4.0 has the maximum customers and the percentage of customers from that city is  10.52

# %% [markdown]
# ##### (7) Which store type sells the maximum products by value and by quantity?

# %%
customer_final.head(2)
# Out:
#    transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351 2014-02-28                 1              1   -5
# 1     29258453508   270384 2014-02-27                 5              3   -5
#
#    Rate      Tax  total_amt Store_type     prod_cat prod_subcat  customer_Id  \
# 0  -772  405.300  -4265.300     e-Shop     Clothing       Women       270351
# 1 -1497  785.925  -8270.925     e-Shop  Electronics   Computers       270384
#
#          DOB Gender  city_code
# 0 1981-09-26      M        5.0
# 1 1973-05-11      F        8.0

# %%
customer_final.groupby("Store_type")["Qty","Rate"].sum().sort_values(by="Qty",ascending=False)
# Out:
#                   Qty     Rate
# Store_type
# e-Shop          22790  5945770
# MBR             11195  2953665
# Flagship store  11142  2942874
# TeleShop        10993  2836359

# %%
print('e-Shop store sell the maximum products by value and by quantity')
# Out:
# e-Shop store sell the maximum products by value and by quantity

# %% [markdown]
# #### (8) What was the total amount earned from the "Electronics" and "Clothing" categories from Flagship Stores?

# %%
store_group = round(customer_final.pivot_table(index = "prod_cat",columns="Store_type",
                                               values="total_amt", aggfunc='sum'),2)

# %%
store_group
# Out:
# Store_type        Flagship store         MBR    TeleShop      e-Shop
# prod_cat
# Bags                   870548.83   848678.68   789181.06  1617933.27
# Books                 2493677.81  2496039.20  2545714.47  5297161.15
# Clothing              1194423.23  1287686.34  1241834.36  2527193.57
# Electronics           2215136.04  2107969.82  1978457.19  4429142.77
# Footwear              1234806.56  1112163.72  1235719.29  2643215.25
# Home and kitchen      1713004.15  1822403.57  1581227.37  3327977.12

# %%
store_group.loc[["Clothing","Electronics"],"Flagship store"]
# Out:
# prod_cat
# Clothing       1194423.23
# Electronics    2215136.04
# Name: Flagship store, dtype: float64

# %%
# if we have to find total amount of both 'Clothing' and 'Electronics' from ' Flagship Store'
store_group.loc[["Clothing","Electronics"],"Flagship store"].sum()
# Out:
# 3409559.27

# %% [markdown]
# #### (9) What was the total amount earned from "Male" customers under the "Electronics" category?

# %%
gender_group = round(customer_final.pivot_table(index = "prod_cat",columns="Gender", values="total_amt", aggfunc='sum'),2)

# %%
gender_group
# Out:
# Gender                     F           M
# prod_cat
# Bags              2079618.84  2046722.99
# Books             6174590.82  6645972.77
# Clothing          3026750.80  3224079.50
# Electronics       5019354.21  5711351.62
# Footwear          3203155.21  3020200.37
# Home and kitchen  4133702.23  4305169.51

# %%
male_earning = gender_group.loc["Electronics","M"]

# %%
print("The total amount earned from Male customers under the Electronics category is",male_earning)
# Out:
# The total amount earned from Male customers under the Electronics category is 5711351.62

# %% [markdown]
# #### (10) How many customers have more than 10 unique transactions, after removing all transactions which have any negative amounts?

# %%
#creating a new dataframe that does not contain transactions with negative values
pos_trans = customer_final.loc[customer_final["total_amt"]>0,:]

# %%
pos_trans
# Out:
#        transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 10        29258453508   270384 2014-02-20                 5              3
# 11        25455265351   267750 2014-02-20                12              6
# 12         1571002198   275023 2014-02-20                 6              5
# 14        36554696014   269345 2014-02-20                 3              5
# 15        56814940239   268799 2014-02-20                 7              5
# 16        54295803788   270787 2014-02-20                12              5
# 17        25963520987   274829 2014-02-20                 4              4
# 18        17183929085   266863 2014-02-20                 1              2
# 19        44783317894   269452 2014-02-20                 3              1
# 20        58957828601   269009 2014-02-20                11              5
# 21         9647515879   268934 2014-02-20                 7              5
# 22        20781077773   269223 2014-02-20                 5              3
# 23        91116291703   268509 2014-02-20                 1              2
# 24        68325723297   268516 2014-02-20                 9              3
# 25        73235813024   268774 2014-02-20                 3              5
# 26        80712190438   270351 2014-02-20                 1              1
# 27        66989395597   272785 2014-02-20                10              3
# 29        99581788104   267466 2014-02-20                 3              2
# 30        28396777609   269101 2014-02-19                 4              1
# 31        22391667321   270842 2014-02-19                 1              2
# 32        51075317246   274987 2014-02-19                10              6
# 33        16199275450   275139 2014-02-19                 4              2
# 34        22698449434   269136 2014-02-19                 7              5
# 35        13167171971   275149 2014-02-19                 4              3
# 36        32130400636   269772 2014-02-19                12              6
# 37        31384765864   267058 2014-02-19                 3              2
# 38        85894118953   271817 2014-02-19                 3              2
# 39        63407734630   271322 2014-02-19                 3              2
# 40        90740728864   268229 2014-02-19                 4              2
# 41        82750983847   267544 2014-02-19                 3              5
# ...               ...      ...        ...               ...            ...
# 23023     87697726895   267014 2011-01-26                 4              4
# 23024     83901074423   270550 2011-01-26                 3              2
# 23025     68490104072   267987 2011-01-26                 3              5
# 23026     98361854847   273273 2011-01-26                 5              3
# 23027     71176929896   269201 2011-01-26                 8              3
# 23028     69487840177   269659 2011-01-26                12              6
# 23029     80212066065   268060 2011-01-26                 1              2
# 23030     78766424618   267618 2011-01-26                11              6
# 23031     83245680995   273723 2011-01-26                 4              4
# 23032     90114483354   268097 2011-01-26                10              5
# 23033     32887353269   268885 2011-01-25                 3              1
# 23034     28972634039   275227 2011-01-25                 9              3
# 23035     42161597232   267094 2011-01-25                 3              1
# 23036     46821751538   269160 2011-01-25                10              5
# 23037      9423947512   267383 2011-01-25                 3              5
# 23038     61812307223   274306 2011-01-25                 4              4
# 23039     62511551321   270394 2011-01-25                 3              2
# 23040     19833039570   271380 2011-01-25                 3              2
# 23041     39737254095   272286 2011-01-25                 2              6
# 23031                Women       273723 1984-01-21      F        4.0
# 23032          Non-Fiction       268097 1992-12-15      F        7.0
# 23033                 Kids       268885 1989-04-14      F        6.0
# 23034              Cameras       275227 1989-09-23      M        4.0
# 23035                 Kids       267094 1992-11-24      M        9.0
# 23036          Non-Fiction       269160 1972-01-24      F        1.0
# 23037               Comics       267383 1984-05-24      M       10.0
# 23038                Women       274306 1989-01-12      M        2.0
# 23039                Women       270394 1978-04-28      F        9.0
# 23040                Women       271380 1977-06-25      F        7.0
# 23041           Furnishing       272286 1983-05-13      M        8.0
# 23042            Computers       273010 1985-08-06      F        4.0
# 23043          Non-Fiction       271982 1976-08-10      M        8.0
# 23044              Mobiles       273982 1991-10-12      M        4.0
# 23045                  DIY       273031 1980-01-17      F        8.0
# 23046                 Bath       272049 1975-06-28      F        6.0
# 23047                 Kids       266866 1974-04-18      M        4.0
# 23048             Academic       274550 1972-02-21      M        7.0
# 23049                 Mens       270022 1984-04-27      M        9.0
# 23050           Furnishing       271020 1976-06-20      M        8.0
# 23051             Children       270911 1970-05-22      M        2.0
# 23052             Children       271961 1982-01-15      M        1.0
#
# [20876 rows x 16 columns]

# %%
# creating a dataframe that contains unique transactions 
unique_trans = pos_trans.groupby(['customer_Id','prod_cat','prod_subcat'])['transaction_id'].count().reset_index()

# %%
unique_trans
# Out:
#        customer_Id          prod_cat          prod_subcat  transaction_id
# 0           266783             Books          Non-Fiction               1
# 1           266783          Clothing                 Mens               2
# 2           266783          Footwear                 Mens               1
# 3           266784             Books              Fiction               1
# 4           266784             Books          Non-Fiction               1
# 5           266784       Electronics              Mobiles               1
# 6           266785              Bags                 Mens               1
# 7           266785             Books             Children               1
# 8           266785          Footwear                 Kids               2
# 9           266785          Footwear                 Mens               2
# 10          266785  Home and kitchen              Kitchen               1
# 11          266788              Bags                 Mens               1
# 12          266788             Books              Fiction               1
# 13          266788          Footwear                 Kids               1
# 14          266788          Footwear                 Mens               1
# 15          266794              Bags                 Mens               1
# 16          266794              Bags                Women               1
# 17          266794             Books             Academic               1
# 18          266794             Books             Children               1
# 19          266794          Clothing                 Kids               2
# 20          266794       Electronics      Audio and video               2
# 21          266794       Electronics  Personal Appliances               1
# 22          266794          Footwear                Women               2
# 23          266799             Books          Non-Fiction               1
# 24          266799       Electronics            Computers               1
# 25          266799  Home and kitchen              Kitchen               1
# 26          266803             Books                  DIY               1
# 27          266804       Electronics            Computers               1
# 28          266805       Electronics  Personal Appliances               1
# 29          266806              Bags                Women               1
# ...            ...               ...                  ...             ...
# 19248       275249       Electronics              Cameras               1
# 19249       275250          Clothing                 Kids               1
# 19250       275250       Electronics      Audio and video               1
# 19251       275250          Footwear                 Kids               1
# 19252       275250          Footwear                 Mens               1
# 19253       275250          Footwear                Women               2
# 19254       275251       Electronics              Cameras               1
# 19255       275251       Electronics              Mobiles               1
# 19256       275252              Bags                 Mens               2
# 19257       275252             Books              Fiction               2
# 19258       275252             Books          Non-Fiction               1
# 19259       275252          Clothing                 Mens               1
# 19260       275252          Clothing                Women               1
# 19261       275252       Electronics  Personal Appliances               1
# 19262       275252          Footwear                 Kids               2
# 19263       275255       Electronics  Personal Appliances               1
# 19264       275257             Books             Children               1
# 19265       275257       Electronics      Audio and video               1
# 19266       275257          Footwear                 Mens               1
# 19267       275257  Home and kitchen           Furnishing               1
# 19268       275261              Bags                Women               1
# 19269       275261             Books             Children               1
# 19270       275261             Books               Comics               1
# 19271       275262          Clothing                 Mens               1
# 19272       275262       Electronics              Cameras               1
# 19273       275264             Books          Non-Fiction               1
# 19274       275264  Home and kitchen                Tools               1
# 19275       275265              Bags                 Mens               1
# 19276       275265             Books             Academic               1
# 19277       275265  Home and kitchen           Furnishing               1
#
# [19278 rows x 4 columns]

# %%
# now finding the customers which have unique transactions greater than 10
unique_trans_count = unique_trans.groupby('customer_Id')['transaction_id'].count().reset_index()

# %%
unique_trans_count.head()
# Out:
#    customer_Id  transaction_id
# 0       266783               3
# 1       266784               3
# 2       266785               5
# 3       266788               4
# 4       266794               8

# %%
unique_trans_count[unique_trans_count['transaction_id'] > 10]
# Out:
# Empty DataFrame
# Columns: [customer_Id, transaction_id]
# Index: []

# %%
print('There are no unique transactions greater than 10')
# Out:
# There are no unique transactions greater than 10

# %% [markdown]
# ##### (11) For all customers aged between 25-35, find out:
# #### (a) What was the total amount spent for 'Electronics' and 'Books' product categories?

# %% [markdown]
# Adding new column 'age'

# %%
now = pd.Timestamp('now')
customer_final['DOB'] = pd.to_datetime(customer_final['DOB'], format='%m%d%y')    # 1
customer_final['DOB'] = customer_final['DOB'].where(customer_final['DOB'] < now, customer_final['DOB'] -  np.timedelta64(100, 'Y'))   # 2
customer_final['AGE'] = (now - customer_final['DOB']).astype('<m8[Y]')

# %%
customer_final.head()
# Out:
#    transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351 2014-02-28                 1              1   -5
# 1     29258453508   270384 2014-02-27                 5              3   -5
# 2     51750724947   273420 2014-02-24                 6              5   -2
# 3     93274880719   271509 2014-02-24                11              6   -3
# 4     51750724947   273420 2014-02-23                 6              5   -2
#
#    Rate      Tax  total_amt Store_type          prod_cat prod_subcat  \
# 0  -772  405.300  -4265.300     e-Shop          Clothing       Women
# 1 -1497  785.925  -8270.925     e-Shop       Electronics   Computers
# 2  -791  166.110  -1748.110   TeleShop             Books         DIY
# 3 -1363  429.345  -4518.345     e-Shop  Home and kitchen        Bath
# 4  -791  166.110  -1748.110   TeleShop             Books         DIY
#
#    customer_Id        DOB Gender  city_code   AGE
# 0       270351 1981-09-26      M        5.0  38.0
# 1       270384 1973-05-11      F        8.0  46.0
# 2       273420 1992-07-27      M        8.0  27.0
# 3       271509 1981-06-08      M        3.0  38.0
# 4       273420 1992-07-27      M        8.0  27.0

# %% [markdown]
# as we have to deal with customers aged between 25-35, so creating new column 'Age_cat'

# %%
customer_final['Age_cat'] = pd.cut(customer_final['AGE'],bins=[24,35,46,57],labels=['25-35','36-46','47-57'],include_lowest=True)

# %%
customer_final.head()
# Out:
#    transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351 2014-02-28                 1              1   -5
# 1     29258453508   270384 2014-02-27                 5              3   -5
# 2     51750724947   273420 2014-02-24                 6              5   -2
# 3     93274880719   271509 2014-02-24                11              6   -3
# 4     51750724947   273420 2014-02-23                 6              5   -2
#
#    Rate      Tax  total_amt Store_type          prod_cat prod_subcat  \
# 0  -772  405.300  -4265.300     e-Shop          Clothing       Women
# 1 -1497  785.925  -8270.925     e-Shop       Electronics   Computers
# 2  -791  166.110  -1748.110   TeleShop             Books         DIY
# 3 -1363  429.345  -4518.345     e-Shop  Home and kitchen        Bath
# 4  -791  166.110  -1748.110   TeleShop             Books         DIY
#
#    customer_Id        DOB Gender  city_code   AGE Age_cat
# 0       270351 1981-09-26      M        5.0  38.0   36-46
# 1       270384 1973-05-11      F        8.0  46.0   36-46
# 2       273420 1992-07-27      M        8.0  27.0   25-35
# 3       271509 1981-06-08      M        3.0  38.0   36-46
# 4       273420 1992-07-27      M        8.0  27.0   25-35

# %%
# grouping the dataframe 'customer_final' on the basis of 'Age_cat' and 'prod_cat'
customer_25_35 = customer_final.groupby(['Age_cat','prod_cat'])['total_amt'].sum()

# %%
customer_25_35
# Out:
# Age_cat  prod_cat
# 25-35    Bags                1531459.280
#          Books               4768585.510
#          Clothing            2586771.850
#          Electronics         4253306.330
#          Footwear            2380744.600
#          Home and kitchen    3234133.890
# 36-46    Bags                2018753.230
#          Books               6340592.765
#          Clothing            2934043.515
#          Electronics         4976742.095
#          Footwear            2963801.165
#          Home and kitchen    4131187.255
# 47-57    Bags                 576129.320
#          Books               1723414.355
#          Clothing             730322.125
#          Electronics         1500657.405
#          Footwear             881359.050
#          Home and kitchen    1079291.070
# Name: total_amt, dtype: float64

# %%
customer_25_35.loc['25-35',['Books','Electronics']]
# Out:
# Age_cat  prod_cat
# 25-35    Books          4768585.51
#          Electronics    4253306.33
# Name: total_amt, dtype: float64

# %%
print("Total amount spent on 'Electronics' and 'Books' product categories is", 
      customer_25_35.loc['25-35',['Books','Electronics']].sum().round(2))
# Out:
# Total amount spent on 'Electronics' and 'Books' product categories is 9021891.84

# %% [markdown]
# #### (b) What was the total amount spent by these customers between 1st Jan 2014 to 1st Mar 2014?

# %%
customer_final.head()
# Out:
#    transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351 2014-02-28                 1              1   -5
# 1     29258453508   270384 2014-02-27                 5              3   -5
# 2     51750724947   273420 2014-02-24                 6              5   -2
# 3     93274880719   271509 2014-02-24                11              6   -3
# 4     51750724947   273420 2014-02-23                 6              5   -2
#
#    Rate      Tax  total_amt Store_type          prod_cat prod_subcat  \
# 0  -772  405.300  -4265.300     e-Shop          Clothing       Women
# 1 -1497  785.925  -8270.925     e-Shop       Electronics   Computers
# 2  -791  166.110  -1748.110   TeleShop             Books         DIY
# 3 -1363  429.345  -4518.345     e-Shop  Home and kitchen        Bath
# 4  -791  166.110  -1748.110   TeleShop             Books         DIY
#
#    customer_Id        DOB Gender  city_code   AGE Age_cat
# 0       270351 1981-09-26      M        5.0  38.0   36-46
# 1       270384 1973-05-11      F        8.0  46.0   36-46
# 2       273420 1992-07-27      M        8.0  27.0   25-35
# 3       271509 1981-06-08      M        3.0  38.0   36-46
# 4       273420 1992-07-27      M        8.0  27.0   25-35

# %%
# filtering out data that belongs to the 'age_cat' = 25-35
customer_total_amount_25_35 = customer_final[customer_final['Age_cat']=='25-35']

# %%
customer_total_amount_25_35.head()
# Out:
#     transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 2      51750724947   273420 2014-02-24                 6              5   -2
# 4      51750724947   273420 2014-02-23                 6              5   -2
# 11     25455265351   267750 2014-02-20                12              6    3
# 13     43134751727   268487 2014-02-20                 3              2   -1
# 17     25963520987   274829 2014-02-20                 4              4    3
#
#     Rate      Tax  total_amt      Store_type          prod_cat prod_subcat  \
# 2   -791  166.110  -1748.110        TeleShop             Books         DIY
# 4   -791  166.110  -1748.110        TeleShop             Books         DIY
# 11  1360  428.400   4508.400          e-Shop  Home and kitchen       Tools
# 13  -611   64.155   -675.155          e-Shop          Footwear       Women
# 17   502  158.130   1664.130  Flagship store              Bags       Women
#
#     customer_Id        DOB Gender  city_code   AGE Age_cat
# 2        273420 1992-07-27      M        8.0  27.0   25-35
# 4        273420 1992-07-27      M        8.0  27.0   25-35
# 11       267750 1986-10-13      M        1.0  33.0   25-35
# 13       268487 1984-06-10      F        2.0  35.0   25-35
# 17       274829 1984-09-05      F        2.0  35.0   25-35

# %%
# getting all the data with transaction date between 1st Jan 2014 to 1st Mar 2014?
total_amount = customer_total_amount_25_35[(customer_total_amount_25_35['tran_date'] >='2014-01-01') & (customer_total_amount_25_35['tran_date'] <='2014-03-01')]

# %%
total_amount
# Out:
#       transaction_id  cust_id  tran_date  prod_subcat_code  prod_cat_code  \
# 2        51750724947   273420 2014-02-24                 6              5
# 4        51750724947   273420 2014-02-23                 6              5
# 11       25455265351   267750 2014-02-20                12              6
# 13       43134751727   268487 2014-02-20                 3              2
# 17       25963520987   274829 2014-02-20                 4              4
# 23       91116291703   268509 2014-02-20                 1              2
# 28       88853694830   268444 2014-02-20                 4              4
# 29       99581788104   267466 2014-02-20                 3              2
# 31       22391667321   270842 2014-02-19                 1              2
# 37       31384765864   267058 2014-02-19                 3              2
# 38       85894118953   271817 2014-02-19                 3              2
# 40       90740728864   268229 2014-02-19                 4              2
# 41       82750983847   267544 2014-02-19                 3              5
# 42       67328698675   268755 2014-02-19                 3              2
# 44       78709566028   273023 2014-02-19                10              6
# 48        7313351894   267568 2014-02-18                 2              6
# 52       58886320392   268715 2014-02-18                10              6
# 59       83313344780   271288 2014-02-18                 4              3
# 60       96923177403   270778 2014-02-18                11              6
# 68       43561027610   270244 2014-02-17                 8              3
# 69       40604748560   269387 2014-02-17                 6              5
# 73       94418788162   267559 2014-02-17                10              6
# 76       88830495604   269018 2014-02-17                10              6
# 77       19729968655   269162 2014-02-16                10              5
# 79       56483064719   270108 2014-02-16                 4              3
# 80       55452156634   273734 2014-02-16                 3              5
# 84       51750724947   273420 2014-02-16                 6              5
# 85       45848212352   268592 2014-02-16                 1              2
# 86       79449440045   271561 2014-02-16                 8              3
# 88       84867095544   267360 2014-02-16                 8              3
# ...              ...      ...        ...               ...            ...
# 989      47023762109   267004 2014-03-01                 2              6
# 994      14752843941   272209 2014-03-01                 2              6
# 996       1856411704   269703 2014-03-01                 1              4
# 997      11678613802   267750 2014-03-01                11              6
# 998      63096895453   270519 2014-03-01                 3              1
# 999      45339814259   273861 2014-03-01                 3              2
# 1002     85804347285   271724 2014-03-01                 4              3
# 1003     85302608197   266841 2014-03-01                 1              1
# 1007     92052844391   267263 2014-03-01                 4              4
# 1009     77232232822   273564 2014-03-01                 3              5
# 1010      7963919490   273350 2014-02-01                 3              2
# 1013     32899104170   270064 2014-02-01                 2              6
# 1018     42716608640   271200 2014-02-01                11              5
# 1023     14302941720   273058 2014-02-01                 1              2
# 1025     32125935023   272067 2014-02-01                10              3
# 1026     50346649770   270616 2014-02-01                 4              2
# 1029     91039584326   272165 2014-02-01                10              5
# 1038       789912743   274000 2014-01-01                10              5
# 1040     16531038014   273230 2014-01-01                 1              1
# 1041     18972312403   272462 2014-01-01                 9              3
# 1043     47595213714   275159 2014-01-01                 2              6
# 1045     26412890125   269365 2014-01-01                 3              1
# 1046     28696753858   270695 2014-01-01                11              5
# 1048     14460826915   269348 2014-01-01                11              6
# 1049     22308679379   267929 2014-01-01                10              5
# 1051     32889219128   269536 2014-01-01                10              5
# 1054     42711619809   271701 2014-01-01                 1              2
# 1059     67088172893   271877 2014-01-01                 1              1
# 1061     63635040022   268886 2014-01-01                 3              2
# 1063     69368153122   273627 2014-01-01                 7              5
#
#       Qty  Rate      Tax  total_amt      Store_type          prod_cat  \
# 2      -2  -791  166.110  -1748.110        TeleShop             Books
# 4      -2  -791  166.110  -1748.110        TeleShop             Books
# 11      3  1360  428.400   4508.400          e-Shop  Home and kitchen
# 13     -1  -611   64.155   -675.155          e-Shop          Footwear
# 17      3   502  158.130   1664.130  Flagship store              Bags
# 23      4  1243  522.060   5494.060             MBR          Footwear
# 28     -3   -80   25.200   -265.200             MBR              Bags
# 29      1    96   10.080    106.080  Flagship store          Footwear
# 31      5   723  379.575   3994.575             MBR          Footwear
# 37      1   793   83.265    876.265          e-Shop          Footwear
# 38      3  1401  441.315   4644.315          e-Shop          Footwear
# 40      5   984  516.600   5436.600        TeleShop          Footwear
# 41      1   805   84.525    889.525  Flagship store             Books
# 42      1  1018  106.890   1124.890  Flagship store          Footwear
# 44      2  1052  220.920   2324.920          e-Shop  Home and kitchen
# 48      4   481  202.020   2126.020  Flagship store  Home and kitchen
# 52      2   768  161.280   1697.280  Flagship store  Home and kitchen
# 59      2    84   17.640    185.640  Flagship store       Electronics
# 60      5  1111  583.275   6138.275             MBR  Home and kitchen
# 68      1   728   76.440    804.440          e-Shop       Electronics
# 69      5   760  399.000   4199.000  Flagship store             Books
# 73      1   620   65.100    685.100        TeleShop  Home and kitchen
# 76      4   307  128.940   1356.940             MBR  Home and kitchen
# 77      2   721  151.410   1593.410          e-Shop             Books
# 79      2  1037  217.770   2291.770          e-Shop       Electronics
# 80      5   778  408.450   4298.450          e-Shop             Books
# 84      2   791  166.110   1748.110        TeleShop             Books
# 85      3  1029  324.135   3411.135        TeleShop          Footwear
# 86      4   498  209.160   2201.160          e-Shop       Electronics
# 88      3   674  212.310   2234.310          e-Shop       Electronics
# ...   ...   ...      ...        ...             ...               ...
# 989     5  1187  623.175   6558.175          e-Shop  Home and kitchen
# 994     2   658  138.180   1454.180          e-Shop  Home and kitchen
# 996     1   855   89.775    944.775             MBR              Bags
# 997    -5 -1235  648.375  -6823.375          e-Shop  Home and kitchen
# 998     1   324   34.020    358.020  Flagship store          Clothing
# 999     2   988  207.480   2183.480          e-Shop          Footwear
# 1002    4   673  282.660   2974.660          e-Shop       Electronics
# 1003    4  1142  479.640   5047.640  Flagship store          Clothing
# 1007    2   523  109.830   1155.830             MBR              Bags
# 1009    3   436  137.340   1445.340          e-Shop             Books
# 1010    5   498  261.450   2751.450             MBR          Footwear
# 994            Furnishing       272209 1991-06-01      F       10.0  28.0
# 996                  Mens       269703 1988-11-17      M        8.0  31.0
# 997                  Bath       267750 1986-10-13      M        1.0  33.0
# 998                  Kids       270519 1986-03-24      F        6.0  33.0
# 999                 Women       273861 1987-01-22      F        5.0  33.0
# 1002              Mobiles       271724 1989-10-21      F        8.0  30.0
# 1003                Women       266841 1991-03-02      M        1.0  29.0
# 1007                Women       267263 1989-09-20      F        6.0  30.0
# 1009               Comics       273564 1992-03-11      F        3.0  27.0
# 1010                Women       273350 1986-10-14      F        5.0  33.0
# 1013           Furnishing       270064 1990-02-22      F        3.0  30.0
# 1018             Children       271200 1986-02-20      M        1.0  34.0
# 1023                 Mens       273058 1989-08-11      F       10.0  30.0
# 1025      Audio and video       272067 1989-05-14      M        5.0  30.0
# 1026                 Kids       270616 1988-08-01      M        9.0  31.0
# 1029          Non-Fiction       272165 1990-12-01      M        4.0  29.0
# 1038          Non-Fiction       274000 1989-08-22      M       10.0  30.0
# 1040                Women       273230 1991-05-29      F        9.0  28.0
# 1041              Cameras       272462 1985-01-02      F        8.0  35.0
# 1043           Furnishing       275159 1992-05-24      F        5.0  27.0
# 1045                 Kids       269365 1992-04-26      M        8.0  27.0
# 1046             Children       270695 1992-12-05      F        6.0  27.0
# 1048                 Bath       269348 1989-02-10      M        9.0  31.0
# 1049          Non-Fiction       267929 1985-02-27      F        9.0  35.0
# 1051          Non-Fiction       269536 1990-03-21      M        5.0  29.0
# 1054                 Mens       271701 1991-07-11      M        7.0  28.0
# 1059                Women       271877 1992-03-28      F        6.0  27.0
# 1061                Women       268886 1992-08-03      M        1.0  27.0
# 1063              Fiction       273627 1985-06-18      M        8.0  34.0
#
#      Age_cat
# 2      25-35
# 4      25-35
# 11     25-35
# 13     25-35
# 17     25-35
# 23     25-35
# 28     25-35
# 29     25-35
# 31     25-35
# 37     25-35
# 38     25-35
# 40     25-35
# 41     25-35
# 42     25-35
# 44     25-35
# 48     25-35
# 52     25-35
# 59     25-35
# 60     25-35
# 68     25-35
# 69     25-35
# 73     25-35
# 76     25-35
# 77     25-35
# 79     25-35
# 80     25-35
# 84     25-35
# 85     25-35
# 86     25-35
# 88     25-35
# ...      ...
# 989    25-35
# 994    25-35
# 996    25-35
# 997    25-35
# 998    25-35
# 999    25-35
# 1002   25-35
# 1003   25-35
# 1007   25-35
# 1009   25-35
# 1010   25-35
# 1013   25-35
# 1018   25-35
# 1023   25-35
# 1025   25-35
# 1026   25-35
# 1029   25-35
# 1038   25-35
# 1040   25-35
# 1041   25-35
# 1043   25-35
# 1045   25-35
# 1046   25-35
# 1048   25-35
# 1049   25-35
# 1051   25-35
# 1054   25-35
# 1059   25-35
# 1061   25-35
# 1063   25-35
#
# [265 rows x 18 columns]

# %%
print('The total amount spent by customers aged 25-35 between 1st Jan 2014 to 1st Mar 2014 is',
      total_amount['total_amt'].sum())
# Out:
# The total amount spent by customers aged 25-35 between 1st Jan 2014 to 1st Mar 2014 is 603037.175
